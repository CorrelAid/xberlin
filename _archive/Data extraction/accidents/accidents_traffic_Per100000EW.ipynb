# %%
#Import the helper functions 'get_all_regions' and 'get_statistics'
#Import the module Query for the main functionality
import os
if not os.path.basename(os.getcwd()) == "datenguide-python":
    os.chdir("..")

from datenguidepy.query_helper import get_regions, get_statistics
from datenguidepy import Query
import pandas as pd
import matplotlib
# %matplotlib inline

pd.set_option('display.max_colwidth', 150)

# %%
#Regions IDs for Germany states
get_regions().query("level == 'nuts1'")
# Out:
#                               name  level parent
# region_id
# 10                        Saarland  nuts1     DG
# 11                          Berlin  nuts1     DG
# 12                     Brandenburg  nuts1     DG
# 13          Mecklenburg-Vorpommern  nuts1     DG
# 14                         Sachsen  nuts1     DG
# 15                  Sachsen-Anhalt  nuts1     DG
# 16                       Thüringen  nuts1     DG
# 01              Schleswig-Holstein  nuts1     DG
# 02                         Hamburg  nuts1     DG
# 03                   Niedersachsen  nuts1     DG
# 04                          Bremen  nuts1     DG
# 05             Nordrhein-Westfalen  nuts1     DG
# 06                          Hessen  nuts1     DG
# 07                 Rheinland-Pfalz  nuts1     DG
# 08         Baden-Württemberg, Land  nuts1     DG
# 09                          Bayern  nuts1     DG

# %%
#wiki == injured in road traffic accidents per 100,000 inhabitants == === === statement The indicator is a measure of the injured in road accidents people. However, the code has the disadvantage that only the local population into account and a high traffic or high commuter traffic affect the result. Differences in car ownership are not considered.
#  === === indicator calculation for the calculation of the indicator 'injured in road traffic accidents per 100,000 population' is the number of injured divided in road accidents in the year by the number of inhabitants on an annual average and multiplied by 100,000.
#  === === origin statistics The indicator is based on data from the statistics of road accidents as well as to the population.
#  === feature descriptions === * '' 'road accidents' ''
#  Proven are those controlled by the police accidents from the reference year 1995, in which were killed or injured as a result of vehicular traffic on public roads and squares persons or material damage. Among the accidents with property damage include serious accidents involving damage to property in the narrow sense in which an offense or a misdemeanor (fine) was present, while at least one vehicle due to an accident damage will be towed from the accident site had, as well as other property damage accidents under the influence of intoxicating substances ( at least one accident participant was under the influence of intoxicating substances, and if car were involved, they were all still roadworthy). Not included are all other property damage accidents without the influence of intoxicating substances. From 1 January 1995, the accidents were established new criteria with property damage within the meaning of the Road Traffic Accident Statistics Act for the acquisition. Unlike previous reporting periods no longer the height of the resulting material damage, but the finding serves as a detection basis whether it is a criminal offense / a misdemeanor and / or at least one accident participant under the influence of alcohol / January 1, 2008 under the influence of intoxicating substances was. the motor pool of vehicles will also be included in the assessment of the accident. Therefore, a comparison with previous years is not possible.
#  * '' 'Accidents involving personal injury' ''
#  This includes accidents, which were killed or injured as a result of vehicular traffic on public roads and squares people.
##  *'''Injured persons'''
#  Maximum age of injured in road traffic accidents, which are delivered directly to hospitals for at least 24 hours for inpatient treatment (= seriously injured) or individuals whose injuries no or hospitalization for less than 24 hours required (= slightly injured).
#  * '' 'Residents' ''
#  To the inhabitants of Germany all people are (German and foreign) who have their permanent residence in Germany. but not to the inhabitants include the members of foreign missions and forces. For the calculation of the indicator 'injured in road traffic accidents per 100,000 inhabitants' annual average number of inhabitants is used. By 2010, the average annual population is the arithmetic average of the twelve monthly averages. These are calculated in each case as the arithmetic mean from the beginning and ending of the relevant month. The average population in 2011 is the date population on 9 May 2011. From 2012, the average annual population mean the average of beginning and year end of year.
#  === === Regional characteristics * Average annual population
##  Baden-Wuerttemberg (1995, 2000), Bavaria, Hesse, North Rhine-Westphalia, Lower Saxony, Rhineland-Palatinate, Saarland (until 1999), Saxony (until 2007) the arithmetic mean of the population at the beginning and end of the year.
#  * Rhineland-Palatinate (2012)
#  The average annual population is the arithmetic average of the twelve monthly averages.
#  === === Further information [https://www.destatis.de/DE/Methoden/Qualitaet/Qualitaetsber eights / traffic accidents / strassenverkehrsunfaelle.pdf | road accidents]
#  [Https://www.destatis.de/DE/Methoden/Qualitaet/Qualitaetsber eights / population / population projection-2017.pdf | population projection]
#  [Https://www.regionalstatistik.de/genesis/online?operation=s tatistikenVerzeichnis | regional database: Areas]

# %%
#meta data
accidents_Killed.get_info()

# %%
#get the data for Injured in road traffic accidents per 100.000EW
query = Query.region(['01', '02', '03','04', '05','06', '07', '08', '09', '10', '11', '12', '13', '14', '15', '16'])
accidents_Killed = query.add_field('AI1305')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id                name  year  AI1305     AI1305_source_title_de  \
# 0   01  Schleswig-Holstein  1995   760.1  Regionalatlas Deutschland
# 1   15      Sachsen-Anhalt  1995   677.9  Regionalatlas Deutschland
# 0   15      Sachsen-Anhalt  1995   677.9  Regionalatlas Deutschland
# 0   03       Niedersachsen  1995   703.1  Regionalatlas Deutschland
# 1   03       Niedersachsen  1995   703.1  Regionalatlas Deutschland
# ..  ..                 ...   ...     ...                        ...
# 29  03       Niedersachsen  2018   531.2  Regionalatlas Deutschland
# 29  02             Hamburg  2018   527.9  Regionalatlas Deutschland
# 29  01  Schleswig-Holstein  2018   550.0  Regionalatlas Deutschland
# 29  15      Sachsen-Anhalt  2018   465.0  Regionalatlas Deutschland
# 29  16           Thüringen  2018   403.4  Regionalatlas Deutschland
#
#    AI1305_source_valid_from AI1305_source_periodicity AI1305_source_name  \
# 0       1995-01-01T00:00:00                 JAEHRLICH              99910
# 1       1995-01-01T00:00:00                 JAEHRLICH              99910
# 0       1995-01-01T00:00:00                 JAEHRLICH              99910
# 0       1995-01-01T00:00:00                 JAEHRLICH              99910
# 1       1995-01-01T00:00:00                 JAEHRLICH              99910
# ..                      ...                       ...                ...
# 29      1995-01-01T00:00:00                 JAEHRLICH              99910
# 29      1995-01-01T00:00:00                 JAEHRLICH              99910
# 29      1995-01-01T00:00:00                 JAEHRLICH              99910
# 29      1995-01-01T00:00:00                 JAEHRLICH              99910
# 29      1995-01-01T00:00:00                 JAEHRLICH              99910
#
#    AI1305_source_url
# 0               None
# 1               None
# 0               None
# 0               None
# 1               None
# ..               ...
# 29              None
# 29              None
# 29              None
# 29              None
# 29              None
#
# [480 rows x 9 columns]
