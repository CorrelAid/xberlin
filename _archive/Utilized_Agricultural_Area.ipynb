# %%
#Import the helper functions 'get_all_regions' and 'get_statistics'
#Import the module Query for the main functionality
import os
if not os.path.basename(os.getcwd()) == "datenguide-python":
    os.chdir("..")

from datenguidepy.query_helper import get_regions, get_statistics
from datenguidepy import Query
import pandas as pd
import matplotlib
# %matplotlib inline

pd.set_option('display.max_colwidth', 150)

# %%
#Regions IDs for Berlin
get_regions().query("name == 'Berlin'")
# Out:
#              name  level parent
# region_id
# 11         Berlin  nuts1     DG
# 110        Berlin  nuts2     11
# 11000      Berlin  nuts3    110

# %%
#Get statistic IDs in English to data that contain "agri" string
get_statistics(target_language = 'en').query('long_description.str.contains("agri")', engine='python')
# Out:
#                                                  short_description  \
# statistic
# FLC048                            LF on farms with organic farming
# ERW046                                                   workforce
# LST009                                                 performance
# BTR034                        Agricultural holdings with livestock
# BTR038                                      Farms with 100 U.M. GV
# VIE003                                                   livestock
# BTR010                                                       farms
# FLC017                                  Utilized agricultural area
# BTR011                                Farms (sole proprietorships)
# BTR030                                  Agricultura. Organic farms
# ETG009                                        Lease payment per ha
# AI0201                       Population density (people per sq km)
# AI0102                         Share recreation area to total area
# ...

# %%
#get the data for farms
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
query.results()
# Out:
#       id    name  year  FLC017  \
# 0    110  Berlin  2016    1845
# 0  11000  Berlin  2016    1845
# 0     11  Berlin  1999    1991
# 1     11  Berlin  2001    1882
# 2     11  Berlin  2003    1811
# 3     11  Berlin  2005    2406
# 4     11  Berlin  2007    2250
# 5     11  Berlin  2010    2182
# 6     11  Berlin  2016    1845
#
#                            FLC017_source_title_de FLC017_source_valid_from  \
# 0  Agrarstrukturerhebung / Landwirtschaftszählung      2010-01-01T00:00:00
# 0  Agrarstrukturerhebung / Landwirtschaftszählung      2010-01-01T00:00:00
# 0     Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1     Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 2     Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 3     Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 4     Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#Utilized agricultural area
#
#  Explanation for the following statistics (s): 41141 agricultural census
#  Connotation: Agricultural area (LF)
#  The area of ​​agricultural (LF) includes all agriculturally or horticulturally exploited areas, including the set-aside land. LF to expect the following specific crops:
# - farmland including horticultural crops, strawberries and greenhouse plants as well as from agricultural production Taken farmland, - permanent pasture including from agricultural production Taken permanent pasture - kitchen gardens, - trees and soft fruit plants (without strawberries) and nuts, - nursery surfaces (without forstliche nurseries for their own use), - vineyards, - Christmas trees (outside the forest) - other permanent crops (eg osier plants), -. permanent crops under glass or other walk-lasting protective devices (without protection and shade nets).
# Short rotation plantations are part of the forest and not used for agricultural area.
# All to an operating mating surfaces are detected in those community in which the operating seat is (operation principle).

# %%
#meta data
Utilized_Agricultural_Area.get_info()
# Out:
# kind:
# OBJECT
#
# description:
# Landwirtschaftlich genutzte Fläche
#
# arguments:
# year: LIST of type SCALAR(Int)
#
# statistics: LIST of type ENUM(FLC017Statistics)
# enum values:
# R41120: Allgemeine Agrarstrukturerhebung (bis 2007)
# R41141: Agrarstrukturerhebung / Landwirtschaftszählung
#
# BEWAT9: LIST of type ENUM(BEWAT9)
# enum values:
# ERWART11: Marktfruchtbetriebe
# ERWART12: Weideviehbetriebe
# ERWART13: Veredlungsbetriebe
# ERWART14: Dauerkulturbetriebe
# ERWART15: Landwirtschaftliche Gemischtbetriebe
# GESAMT: Gesamt
#
# FRUNW2: LIST of type ENUM(FRUNW2)
# enum values:
# FRUART0111: Weizen
# FRUART0112: Roggen
# FRUART01211: Wintergerste
# FRUART01212: Sommergerste
# FRUART0122: Hafer
# FRUART0124: Triticale
# ZUSAMMEN01: zusammen
# GESAMT: Gesamt
#
# BEWAT7: LIST of type ENUM(BEWAT7)
# enum values:
# ERWART09: Ackerbaubetriebe
# ERWART10: Gartenbaubetriebe
# ERWART12: Weideviehbetriebe
# ERWART13: Veredlungsbetriebe
# ERWART14: Dauerkulturbetriebe
# ...

# %%
#Agricultural operating modes
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'BEWAT9': 'ALL'})
Utilized_Agricultural_Area.add_field('BEWAT9')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name                                BEWAT9  year  FLC017  \
# 0      11  Berlin                   Marktfruchtbetriebe  1999    1372
# 1      11  Berlin  Landwirtschaftliche Gemischtbetriebe  1999     105
# 2      11  Berlin                     Weideviehbetriebe  1999     291
# 3      11  Berlin                    Veredlungsbetriebe  1999       1
# 4      11  Berlin                                Gesamt  1999    1991
# 5      11  Berlin                                Gesamt  2001    1882
# 6      11  Berlin                                Gesamt  2003    1811
# 7      11  Berlin                                Gesamt  2005    2406
# 8      11  Berlin                                Gesamt  2007    2250
# 9      11  Berlin                                Gesamt  2010    2182
# 0     110  Berlin                                Gesamt  2016    1845
# 0   11000  Berlin                                Gesamt  2016    1845
# ...

# %%
#cereals
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'FRUNW2': 'ALL'})
Utilized_Agricultural_Area.add_field('FRUNW2')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name        FRUNW2  year  FLC017  \
# 0      11  Berlin  Sommergerste  1999      21
# 1      11  Berlin     Triticale  1999      26
# 2      11  Berlin        Weizen  1999      10
# 3      11  Berlin      zusammen  1999     749
# 4      11  Berlin        Roggen  1999     616
# 5      11  Berlin         Hafer  1999      60
# 6      11  Berlin        Gesamt  1999    1991
# 7      11  Berlin        Gesamt  2001    1882
# 12     11  Berlin     Triticale  2003      96
# 15     11  Berlin        Gesamt  2003    1811
# 14     11  Berlin  Wintergerste  2003       0
# 13     11  Berlin         Hafer  2003      56
# 11     11  Berlin        Weizen  2003      64
# 10     11  Berlin  Sommergerste  2003      28
# 9      11  Berlin        Roggen  2003     371
# 8      11  Berlin      zusammen  2003     652
# 16     11  Berlin        Gesamt  2005    2406
# 24     11  Berlin        Gesamt  2007    2250
# 17     11  Berlin      zusammen  2007     732
# ...

# %%
#Business Orientation (BWA)
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'BEWAT7': 'ALL'})
Utilized_Agricultural_Area.add_field('BEWAT7')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name                              BEWAT7  year  FLC017  \
# 0      11  Berlin                              Gesamt  1999    1991
# 1      11  Berlin                              Gesamt  2001    1882
# 9      11  Berlin                  Veredlungsbetriebe  2003       0
# 7      11  Berlin  Pflanzenbau - Viehhaltungsbetriebe  2003       0
# 6      11  Berlin         Viehhaltungsverbundbetriebe  2003       0
# 5      11  Berlin                   Gartenbaubetriebe  2003      95
# 8      11  Berlin                              Gesamt  2003    1811
# 3      11  Berlin                   Weideviehbetriebe  2003     265
# 2      11  Berlin                    Ackerbaubetriebe  2003    1194
# 4      11  Berlin          Pflanzenbauverbundbetriebe  2003       0
# 10     11  Berlin                              Gesamt  2005    2406
# 19     11  Berlin         Viehhaltungsverbundbetriebe  2007       0
# 17     11  Berlin                   Gartenbaubetriebe  2007     246
# ...

# %%
#arable land
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'FRUNW1': 'ALL'})
Utilized_Agricultural_Area.add_field('FRUNW1')
query.results(verbose_enums=True).sort_values('year')
# Out:
#       id    name               FRUNW1  year  FLC017  \
# 0     11  Berlin               Gesamt  1999    1991
# 1     11  Berlin  Ackerland insgesamt  1999    1377
# 2     11  Berlin               Gesamt  2001    1882
# 3     11  Berlin  Ackerland insgesamt  2003    1225
# 4     11  Berlin               Gesamt  2003    1811
# 5     11  Berlin               Gesamt  2005    2406
# 6     11  Berlin               Gesamt  2007    2250
# 7     11  Berlin  Ackerland insgesamt  2007    1587
# 8     11  Berlin               Gesamt  2010    2182
# 0    110  Berlin               Gesamt  2016    1845
# 0  11000  Berlin               Gesamt  2016    1845
# 9     11  Berlin               Gesamt  2016    1845
#
#                            FLC017_source_title_de FLC017_source_valid_from  \
# 0     Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1     Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#size classes of agricultural used area (LF)
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'FLCGNW': 'ALL'})
Utilized_Agricultural_Area.add_field('FLCGNW')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name               FLCGNW  year  FLC017  \
# 7      11  Berlin               Gesamt  1999    1991
# 0      11  Berlin           unter 2 ha  1999      29
# 1      11  Berlin     2 bis unter 5 ha  1999      25
# 2      11  Berlin    5 bis unter 10 ha  1999      35
# 3      11  Berlin   10 bis unter 20 ha  1999     111
# 4      11  Berlin   30 bis unter 50 ha  1999     370
# 5      11  Berlin   50 bis unter 75 ha  1999     593
# 6      11  Berlin      100 und mehr ha  1999     573
# 14     11  Berlin   50 bis unter 75 ha  2001     536
# 13     11  Berlin   30 bis unter 50 ha  2001     297
# 12     11  Berlin   20 bis unter 30 ha  2001      69
# 11     11  Berlin   10 bis unter 20 ha  2001     111
# 9      11  Berlin     2 bis unter 5 ha  2001      27
# 17     11  Berlin               Gesamt  2001    1882
# 8      11  Berlin           unter 2 ha  2001      21
# 15     11  Berlin  75 bis unter 100 ha  2001     233
# 10     11  Berlin    5 bis unter 10 ha  2001      27
# ...

# %%
#Cultures
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'KULAT9': 'ALL'})
Utilized_Agricultural_Area.add_field('KULAT9')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name               KULAT9  year  FLC017  \
# 0      11  Berlin    mit Dauerkulturen  1999      62
# 1      11  Berlin    mit Dauergrünland  1999     552
# 2      11  Berlin  Ackerland insgesamt  1999    1377
# 3      11  Berlin               Gesamt  1999    1991
# 4      11  Berlin    mit Dauerkulturen  2001      53
# 5      11  Berlin    mit Dauergrünland  2001     542
# 6      11  Berlin  Ackerland insgesamt  2001    1288
# 7      11  Berlin               Gesamt  2001    1882
# 9      11  Berlin    mit Dauerkulturen  2003      52
# 11     11  Berlin               Gesamt  2003    1811
# 10     11  Berlin  Ackerland insgesamt  2003    1225
# 8      11  Berlin    mit Dauergrünland  2003     534
# 12     11  Berlin  Ackerland insgesamt  2005    1432
# 13     11  Berlin    mit Dauerkulturen  2005       0
# 14     11  Berlin    mit Dauergrünland  2005     925
# 15     11  Berlin               Gesamt  2005    2406
# 17     11  Berlin    mit Dauerkulturen  2007       0
# ...

# %%
#commercial plants
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'FRUNW5': 'ALL'})
Utilized_Agricultural_Area.add_field('FRUNW5')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name      FRUNW5  year  FLC017  \
# 0      11  Berlin  Winterraps  1999      24
# 1      11  Berlin    zusammen  1999      96
# 2      11  Berlin      Gesamt  1999    1991
# 3      11  Berlin      Gesamt  2001    1882
# 4      11  Berlin  Winterraps  2003      65
# 5      11  Berlin    zusammen  2003      77
# 6      11  Berlin      Gesamt  2003    1811
# 7      11  Berlin      Gesamt  2005    2406
# 8      11  Berlin  Winterraps  2007      92
# 9      11  Berlin    zusammen  2007      95
# 10     11  Berlin      Gesamt  2007    2250
# 11     11  Berlin      Gesamt  2010    2182
# 0     110  Berlin      Gesamt  2016    1845
# 0   11000  Berlin      Gesamt  2016    1845
# 12     11  Berlin      Gesamt  2016    1845
#
#                             FLC017_source_title_de FLC017_source_valid_from  \
# 0      Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1      Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#root crops
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'FRUNW3': 'ALL'})
Utilized_Agricultural_Area.add_field('FRUNW3')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name       FRUNW3  year  FLC017  \
# 0      11  Berlin   Kartoffeln  1999       0
# 1      11  Berlin     zusammen  1999      14
# 2      11  Berlin  Zuckerrüben  1999       0
# 3      11  Berlin       Gesamt  1999    1991
# 4      11  Berlin       Gesamt  2001    1882
# 6      11  Berlin     zusammen  2003      18
# 5      11  Berlin   Kartoffeln  2003       0
# 7      11  Berlin       Gesamt  2003    1811
# 8      11  Berlin       Gesamt  2005    2406
# 12     11  Berlin       Gesamt  2007    2250
# 9      11  Berlin   Kartoffeln  2007       0
# 10     11  Berlin  Zuckerrüben  2007       0
# 11     11  Berlin     zusammen  2007      23
# 13     11  Berlin       Gesamt  2010    2182
# 0     110  Berlin       Gesamt  2016    1845
# 0   11000  Berlin       Gesamt  2016    1845
# 14     11  Berlin       Gesamt  2016    1845
#
#                             FLC017_source_title_de FLC017_source_valid_from  \
# ...

# %%
#size class of standard operating income
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'UMSGR9': 'ALL'})
Utilized_Agricultural_Area.add_field('UMSGR9')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name                  UMSGR9  year  FLC017  \
# 6      11  Berlin    10,2 - 15,3 Tsd. EUR  1999     303
# 0      11  Berlin     5,1 - 10,2 Tsd. EUR  1999     297
# 1      11  Berlin    25,6 - 38,3 Tsd. EUR  1999     144
# 2      11  Berlin    38,3 - 51,1 Tsd. EUR  1999     230
# 3      11  Berlin      2,6 - 5,1 Tsd. EUR  1999      68
# 4      11  Berlin    15,3 - 25,6 Tsd. EUR  1999     506
# 5      11  Berlin  51,1 Tsd. EUR und mehr  1999     380
# 7      11  Berlin      unter 2,6 Tsd. EUR  1999      62
# 8      11  Berlin                  Gesamt  1999    1991
# 9      11  Berlin                  Gesamt  2001    1882
# 10     11  Berlin                  Gesamt  2003    1811
# 11     11  Berlin                  Gesamt  2005    2406
# 12     11  Berlin                  Gesamt  2007    2250
# 13     11  Berlin                  Gesamt  2010    2182
# 0     110  Berlin                  Gesamt  2016    1845
# 0   11000  Berlin                  Gesamt  2016    1845
# ...

# %%
#Size classes of the standard contribution margin (SDB)
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'SDBGNW': 'ALL'})
Utilized_Agricultural_Area.add_field('SDBGNW')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name               SDBGNW  year  FLC017  \
# 0      11  Berlin               Gesamt  1999    1991
# 1      11  Berlin               Gesamt  2001    1882
# 10     11  Berlin               Gesamt  2003    1811
# 9      11  Berlin     60 oder mehr EGE  2003     682
# 7      11  Berlin  32 bis unter 40 EGE  2003       0
# 6      11  Berlin  24 bis unter 32 EGE  2003     196
# 5      11  Berlin  16 bis unter 24 EGE  2003     183
# 8      11  Berlin  40 bis unter 60 EGE  2003     120
# 3      11  Berlin    2 bis unter 8 EGE  2003     226
# 2      11  Berlin          unter 2 EGE  2003       9
# 4      11  Berlin   8 bis unter 16 EGE  2003       0
# 11     11  Berlin               Gesamt  2005    2406
# 18     11  Berlin  40 bis unter 60 EGE  2007     163
# 20     11  Berlin               Gesamt  2007    2250
# 12     11  Berlin          unter 2 EGE  2007      17
# 13     11  Berlin    2 bis unter 8 EGE  2007     341
# 14     11  Berlin   8 bis unter 16 EGE  2007     443
# ...

# %%
#fodder plants
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'FRUNW4': 'ALL'})
Utilized_Agricultural_Area.add_field('FRUNW4')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name    FRUNW4  year  FLC017  \
# 0      11  Berlin  zusammen  1999     194
# 1      11  Berlin  Silomais  1999      35
# 2      11  Berlin    Gesamt  1999    1991
# 3      11  Berlin    Gesamt  2001    1882
# 4      11  Berlin  zusammen  2003     138
# 5      11  Berlin  Silomais  2003      32
# 6      11  Berlin    Gesamt  2003    1811
# 7      11  Berlin    Gesamt  2005    2406
# 8      11  Berlin  Silomais  2007      20
# 9      11  Berlin  zusammen  2007     308
# 10     11  Berlin    Gesamt  2007    2250
# 11     11  Berlin    Gesamt  2010    2182
# 0     110  Berlin    Gesamt  2016    1845
# 0   11000  Berlin    Gesamt  2016    1845
# 12     11  Berlin    Gesamt  2016    1845
#
#                             FLC017_source_title_de FLC017_source_valid_from  \
# 0      Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1      Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#type of management
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'BTRAT1': 'ALL'})
Utilized_Agricultural_Area.add_field('BTRAT1')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name                                     BTRAT1  year  FLC017  \
# 0      11  Berlin   Landw. Betriebe mit ökologischem Landbau  1999     106
# 1      11  Berlin  Landw. Betriebe ohne ökologischen Landbau  1999    1834
# 2      11  Berlin                                     Gesamt  1999    1991
# 3      11  Berlin  Landw. Betriebe ohne ökologischen Landbau  2001    1882
# 4      11  Berlin                                     Gesamt  2001    1882
# 6      11  Berlin  Landw. Betriebe ohne ökologischen Landbau  2003    1780
# 5      11  Berlin   Landw. Betriebe mit ökologischem Landbau  2003      31
# 7      11  Berlin                                     Gesamt  2003    1811
# 8      11  Berlin  Landw. Betriebe ohne ökologischen Landbau  2005    2375
# 9      11  Berlin   Landw. Betriebe mit ökologischem Landbau  2005      31
# 10     11  Berlin                                     Gesamt  2005    2406
# ...

# %%
#type of operation
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'BEWAT2': 'ALL'})
Utilized_Agricultural_Area.add_field('BEWAT2')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name                BEWAT2  year  FLC017  \
# 0      11  Berlin                Gesamt  1999    1991
# 1      11  Berlin  Haupterwerbsbetriebe  1999    1168
# 2      11  Berlin  Nebenerwerbsbetriebe  1999     236
# 3      11  Berlin       übrige Betriebe  1999     587
# 4      11  Berlin                Gesamt  2001    1882
# 6      11  Berlin       übrige Betriebe  2003     585
# 5      11  Berlin  Haupterwerbsbetriebe  2003    1116
# 7      11  Berlin                Gesamt  2003    1811
# 8      11  Berlin  Nebenerwerbsbetriebe  2003     110
# 9      11  Berlin                Gesamt  2005    2406
# 13     11  Berlin       übrige Betriebe  2007     748
# 10     11  Berlin                Gesamt  2007    2250
# 11     11  Berlin  Haupterwerbsbetriebe  2007    1303
# 12     11  Berlin  Nebenerwerbsbetriebe  2007     199
# 14     11  Berlin                Gesamt  2010    2182
# 0     110  Berlin                Gesamt  2016    1845
# ...

# %%
#LF size classes
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'FLCG06': 'ALL'})
Utilized_Agricultural_Area.add_field('FLCG06')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name                FLCG06  year  FLC017  \
# 0      11  Berlin                Gesamt  1999    1991
# 1      11  Berlin                Gesamt  2001    1882
# 2      11  Berlin                Gesamt  2003    1811
# 3      11  Berlin                Gesamt  2005    2406
# 4      11  Berlin                Gesamt  2007    2250
# 12     11  Berlin       200 und mehr ha  2010       0
# 11     11  Berlin  100 bis unter 200 ha  2010     874
# 9      11  Berlin    20 bis unter 50 ha  2010     429
# 8      11  Berlin    10 bis unter 20 ha  2010     124
# 7      11  Berlin     5 bis unter 10 ha  2010       0
# 6      11  Berlin            unter 5 ha  2010       0
# 5      11  Berlin                Gesamt  2010    2182
# 10     11  Berlin   50 bis unter 100 ha  2010     426
# 15     11  Berlin     5 bis unter 10 ha  2016       0
# 14     11  Berlin            unter 5 ha  2016      25
# 13     11  Berlin                Gesamt  2016    1845
# ...

# %%
#LF size classes
query = Query.region(['110', '11000', '11'])
Utilized_Agricultural_Area = query.add_field('FLC017')
Utilized_Agricultural_Area.add_args({'EIGVH1': 'ALL'})
Utilized_Agricultural_Area.add_field('EIGVH1')
query.results(verbose_enums=True).sort_values('year')
