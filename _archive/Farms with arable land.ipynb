# %%
#Import the helper functions 'get_all_regions' and 'get_statistics'
#Import the module Query for the main functionality
import os
if not os.path.basename(os.getcwd()) == "datenguide-python":
    os.chdir("..")

from datenguidepy.query_helper import get_regions, get_statistics
from datenguidepy import Query
import pandas as pd
import matplotlib
# %matplotlib inline

pd.set_option('display.max_colwidth', 150)

# %%
#Regions IDs for Berlin
get_regions().query("name == 'Berlin'")
# Out:
#              name  level parent
# region_id
# 11         Berlin  nuts1     DG
# 110        Berlin  nuts2     11
# 11000      Berlin  nuts3    110

# %%
#Get statistic IDs in English to data that contain "agri" string
get_statistics(target_language = 'en').query('long_description.str.contains("agri")', engine='python')
# Out:
#                                                  short_description  \
# statistic
# FLC048                            LF on farms with organic farming
# ERW046                                                   workforce
# LST009                                                 performance
# BTR034                        Agricultural holdings with livestock
# BTR038                                      Farms with 100 U.M. GV
# VIE003                                                   livestock
# BTR010                                                       farms
# FLC017                                  Utilized agricultural area
# BTR011                                Farms (sole proprietorships)
# BTR030                                  Agricultura. Organic farms
# ETG009                                        Lease payment per ha
# AI0201                       Population density (people per sq km)
# AI0102                         Share recreation area to total area
# ...

# %%
#get the data for Farms with arable land
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
query.results()
# Out:
#    id    name    year  BETR09                       BETR09_source_title_de  \
# 0  11  Berlin  1999.0   103.0  Allgemeine Agrarstrukturerhebung (bis 2007)
# 1  11  Berlin  2001.0    90.0  Allgemeine Agrarstrukturerhebung (bis 2007)
# 2  11  Berlin  2003.0    86.0  Allgemeine Agrarstrukturerhebung (bis 2007)
# 3  11  Berlin  2005.0    89.0  Allgemeine Agrarstrukturerhebung (bis 2007)
# 4  11  Berlin  2007.0    85.0  Allgemeine Agrarstrukturerhebung (bis 2007)
#
#   BETR09_source_valid_from BETR09_source_periodicity BETR09_source_name  \
# 0      1999-05-31T00:00:00             ZWEIJAEHRLICH              41120
# 1      1999-05-31T00:00:00             ZWEIJAEHRLICH              41120
# 2      1999-05-31T00:00:00             ZWEIJAEHRLICH              41120
# 3      1999-05-31T00:00:00             ZWEIJAEHRLICH              41120
# 4      1999-05-31T00:00:00             ZWEIJAEHRLICH              41120
#
#   BETR09_source_url
# 0              None
# 1              None
# ...

# %%
#farms
#  Explanation for the following statistics (s): 41121 Farm Structure Survey
#  Connotation: On a farm (including horticulture and viticulture) a technical and economic unity is understood to be for the account of the holder (the holder) is managed, under single management and produces agricultural products.

# %%
#meta data
Farms_Arable.get_info()
# Out:
# kind:
# OBJECT
#
# description:
# Landwirtschaftliche Betriebe mit Ackerland
#
# arguments:
# year: LIST of type SCALAR(Int)
#
# statistics: LIST of type ENUM(BETR09Statistics)
# enum values:
# R41120: Allgemeine Agrarstrukturerhebung (bis 2007)
#
# BEWAT9: LIST of type ENUM(BEWAT9)
# enum values:
# ERWART11: Marktfruchtbetriebe
# ERWART12: Weideviehbetriebe
# ERWART13: Veredlungsbetriebe
# ERWART14: Dauerkulturbetriebe
# ERWART15: Landwirtschaftliche Gemischtbetriebe
# GESAMT: Gesamt
#
# FRUNW2: LIST of type ENUM(FRUNW2)
# enum values:
# FRUART0111: Weizen
# FRUART0112: Roggen
# FRUART01211: Wintergerste
# FRUART01212: Sommergerste
# FRUART0122: Hafer
# FRUART0124: Triticale
# ZUSAMMEN01: zusammen
# GESAMT: Gesamt
#
# BEWAT7: LIST of type ENUM(BEWAT7)
# enum values:
# ERWART09: Ackerbaubetriebe
# ERWART10: Gartenbaubetriebe
# ERWART12: Weideviehbetriebe
# ERWART13: Veredlungsbetriebe
# ERWART14: Dauerkulturbetriebe
# ERWART16: Pflanzenbauverbundbetriebe
# ...

# %%
#Agricultural modes
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'BEWAT9': 'ALL'})
Farms_Arable.add_field('BEWAT9')
query.results(verbose_enums=True).sort_values('year')
# Out:
#    id    name    year                                BEWAT9  BETR09  \
# 0  11  Berlin  1999.0                   Marktfruchtbetriebe    26.0
# 1  11  Berlin  1999.0  Landwirtschaftliche Gemischtbetriebe     2.0
# 2  11  Berlin  1999.0                     Weideviehbetriebe    10.0
# 3  11  Berlin  1999.0                    Veredlungsbetriebe     4.0
# 4  11  Berlin  1999.0                                Gesamt   103.0
# 5  11  Berlin  2001.0                                Gesamt    90.0
# 6  11  Berlin  2003.0                                Gesamt    86.0
# 7  11  Berlin  2005.0                                Gesamt    89.0
# 8  11  Berlin  2007.0                                Gesamt    85.0
#
#                         BETR09_source_title_de BETR09_source_valid_from  \
# 0  Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1  Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#grain
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'FRUNW2': 'ALL'})
Farms_Arable.add_field('FRUNW2')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year        FRUNW2  BETR09  \
# 0   11  Berlin  1999.0  Sommergerste     6.0
# 1   11  Berlin  1999.0     Triticale     4.0
# 2   11  Berlin  1999.0        Weizen     4.0
# 3   11  Berlin  1999.0      zusammen    28.0
# 4   11  Berlin  1999.0        Roggen    25.0
# 5   11  Berlin  1999.0         Hafer    10.0
# 6   11  Berlin  1999.0        Gesamt   103.0
# 7   11  Berlin  2001.0        Gesamt    90.0
# 15  11  Berlin  2003.0        Gesamt    86.0
# 14  11  Berlin  2003.0  Wintergerste     0.0
# 13  11  Berlin  2003.0         Hafer     9.0
# 12  11  Berlin  2003.0     Triticale     5.0
# 10  11  Berlin  2003.0  Sommergerste     7.0
# 9   11  Berlin  2003.0        Roggen    18.0
# 8   11  Berlin  2003.0      zusammen    23.0
# 11  11  Berlin  2003.0        Weizen     5.0
# 16  11  Berlin  2005.0        Gesamt    89.0
# 23  11  Berlin  2007.0         Hafer     0.0
# 17  11  Berlin  2007.0      zusammen    23.0
# 18  11  Berlin  2007.0     Triticale     0.0
# ...

# %%
#Business Administration (BWA)
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'BEWAT7': 'ALL'})
Farms_Arable.add_field('BEWAT7')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name                              BEWAT7    year  BETR09  \
# 0   11  Berlin                              Gesamt  1999.0   103.0
# 1   11  Berlin                              Gesamt  2001.0    90.0
# 8   11  Berlin                              Gesamt  2003.0    86.0
# 7   11  Berlin  Pflanzenbau - Viehhaltungsbetriebe  2003.0     0.0
# 6   11  Berlin         Viehhaltungsverbundbetriebe  2003.0     0.0
# 9   11  Berlin                  Veredlungsbetriebe  2003.0     0.0
# 4   11  Berlin          Pflanzenbauverbundbetriebe  2003.0     0.0
# 3   11  Berlin                   Weideviehbetriebe  2003.0    10.0
# 2   11  Berlin                    Ackerbaubetriebe  2003.0    21.0
# 5   11  Berlin                   Gartenbaubetriebe  2003.0    47.0
# 10  11  Berlin                              Gesamt  2005.0    89.0
# 18  11  Berlin                  Veredlungsbetriebe  2007.0     0.0
# 11  11  Berlin                   Weideviehbetriebe  2007.0    20.0
# ...

# %%
#farmland
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'FRUNW1': 'ALL'})
Farms_Arable.add_field('FRUNW1')
query.results(verbose_enums=True).sort_values('year')
# Out:
#    id    name    year               FRUNW1  BETR09  \
# 0  11  Berlin  1999.0               Gesamt   103.0
# 1  11  Berlin  1999.0  Ackerland insgesamt    91.0
# 2  11  Berlin  2001.0               Gesamt    90.0
# 3  11  Berlin  2003.0  Ackerland insgesamt    75.0
# 4  11  Berlin  2003.0               Gesamt    86.0
# 5  11  Berlin  2005.0               Gesamt    89.0
# 6  11  Berlin  2007.0               Gesamt    85.0
# 7  11  Berlin  2007.0  Ackerland insgesamt    72.0
#
#                         BETR09_source_title_de BETR09_source_valid_from  \
# 0  Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1  Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 2  Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 3  Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 4  Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#size classes of agr. used area (LF)
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'FLCGNW': 'ALL'})
Farms_Arable.add_field('FLCGNW')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year               FLCGNW  BETR09  \
# 0   11  Berlin  1999.0           unter 2 ha    54.0
# 1   11  Berlin  1999.0     2 bis unter 5 ha     8.0
# 2   11  Berlin  1999.0    5 bis unter 10 ha     5.0
# 3   11  Berlin  1999.0   10 bis unter 20 ha     8.0
# 4   11  Berlin  1999.0   30 bis unter 50 ha    10.0
# 5   11  Berlin  1999.0   50 bis unter 75 ha    10.0
# 6   11  Berlin  1999.0      100 und mehr ha     4.0
# 7   11  Berlin  1999.0               Gesamt   103.0
# 17  11  Berlin  2001.0               Gesamt    90.0
# 16  11  Berlin  2001.0      100 und mehr ha     4.0
# 15  11  Berlin  2001.0  75 bis unter 100 ha     3.0
# 14  11  Berlin  2001.0   50 bis unter 75 ha     9.0
# 13  11  Berlin  2001.0   30 bis unter 50 ha     8.0
# 10  11  Berlin  2001.0    5 bis unter 10 ha     4.0
# 11  11  Berlin  2001.0   10 bis unter 20 ha     8.0
# 9   11  Berlin  2001.0     2 bis unter 5 ha     9.0
# 8   11  Berlin  2001.0           unter 2 ha    42.0
# ...

# %%
#Cultures
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'KULAT9': 'ALL'})
Farms_Arable.add_field('KULAT9')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year               KULAT9  BETR09  \
# 0   11  Berlin  1999.0    mit Dauerkulturen    13.0
# 1   11  Berlin  1999.0    mit Dauergrünland    27.0
# 2   11  Berlin  1999.0  Ackerland insgesamt    91.0
# 3   11  Berlin  1999.0               Gesamt   103.0
# 4   11  Berlin  2001.0    mit Dauerkulturen    11.0
# 5   11  Berlin  2001.0    mit Dauergrünland    25.0
# 6   11  Berlin  2001.0  Ackerland insgesamt    80.0
# 7   11  Berlin  2001.0               Gesamt    90.0
# 11  11  Berlin  2003.0               Gesamt    86.0
# 10  11  Berlin  2003.0  Ackerland insgesamt    75.0
# 9   11  Berlin  2003.0    mit Dauerkulturen    10.0
# 8   11  Berlin  2003.0    mit Dauergrünland    25.0
# 12  11  Berlin  2005.0  Ackerland insgesamt    75.0
# 13  11  Berlin  2005.0    mit Dauerkulturen     0.0
# 14  11  Berlin  2005.0    mit Dauergrünland    33.0
# 15  11  Berlin  2005.0               Gesamt    89.0
# 16  11  Berlin  2007.0  Ackerland insgesamt    72.0
# ...

# %%
# commercial crops
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'FRUNW5': 'ALL'})
Farms_Arable.add_field('FRUNW5')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year      FRUNW5  BETR09  \
# 0   11  Berlin  1999.0  Winterraps     4.0
# 1   11  Berlin  1999.0    zusammen     9.0
# 2   11  Berlin  1999.0      Gesamt   103.0
# 3   11  Berlin  2001.0      Gesamt    90.0
# 4   11  Berlin  2003.0  Winterraps     7.0
# 5   11  Berlin  2003.0    zusammen     8.0
# 6   11  Berlin  2003.0      Gesamt    86.0
# 7   11  Berlin  2005.0      Gesamt    89.0
# 8   11  Berlin  2007.0  Winterraps     5.0
# 9   11  Berlin  2007.0    zusammen     9.0
# 10  11  Berlin  2007.0      Gesamt    85.0
#
#                          BETR09_source_title_de BETR09_source_valid_from  \
# 0   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 2   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 3   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 4   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
# root crops
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'FRUNW3': 'ALL'})
Farms_Arable.add_field('FRUNW3')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year       FRUNW3  BETR09  \
# 0   11  Berlin  1999.0   Kartoffeln     0.0
# 1   11  Berlin  1999.0     zusammen     6.0
# 2   11  Berlin  1999.0  Zuckerrüben     0.0
# 3   11  Berlin  1999.0       Gesamt   103.0
# 4   11  Berlin  2001.0       Gesamt    90.0
# 5   11  Berlin  2003.0   Kartoffeln     0.0
# 6   11  Berlin  2003.0     zusammen     4.0
# 7   11  Berlin  2003.0       Gesamt    86.0
# 8   11  Berlin  2005.0       Gesamt    89.0
# 9   11  Berlin  2007.0   Kartoffeln     0.0
# 10  11  Berlin  2007.0  Zuckerrüben     0.0
# 11  11  Berlin  2007.0     zusammen     9.0
# 12  11  Berlin  2007.0       Gesamt    85.0
#
#                          BETR09_source_title_de BETR09_source_valid_from  \
# 0   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 2   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#Size class of the standard operating income
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'UMSGR9': 'ALL'})
Farms_Arable.add_field('UMSGR9')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year                  UMSGR9  BETR09  \
# 0   11  Berlin  1999.0     5,1 - 10,2 Tsd. EUR    10.0
# 1   11  Berlin  1999.0    25,6 - 38,3 Tsd. EUR     8.0
# 2   11  Berlin  1999.0    38,3 - 51,1 Tsd. EUR     9.0
# 3   11  Berlin  1999.0      2,6 - 5,1 Tsd. EUR     4.0
# 4   11  Berlin  1999.0    15,3 - 25,6 Tsd. EUR    12.0
# 5   11  Berlin  1999.0  51,1 Tsd. EUR und mehr    42.0
# 6   11  Berlin  1999.0    10,2 - 15,3 Tsd. EUR     9.0
# 7   11  Berlin  1999.0      unter 2,6 Tsd. EUR     9.0
# 8   11  Berlin  1999.0                  Gesamt   103.0
# 9   11  Berlin  2001.0                  Gesamt    90.0
# 10  11  Berlin  2003.0                  Gesamt    86.0
# 11  11  Berlin  2005.0                  Gesamt    89.0
# 12  11  Berlin  2007.0                  Gesamt    85.0
#
#                          BETR09_source_title_de BETR09_source_valid_from  \
# 0   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#size classes of the standard contribution margin (SDB)
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'SDBGNW': 'ALL'})
Farms_Arable.add_field('SDBGNW')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year               SDBGNW  BETR09  \
# 0   11  Berlin  1999.0               Gesamt   103.0
# 1   11  Berlin  2001.0               Gesamt    90.0
# 9   11  Berlin  2003.0     60 oder mehr EGE    36.0
# 8   11  Berlin  2003.0  40 bis unter 60 EGE     7.0
# 7   11  Berlin  2003.0  32 bis unter 40 EGE     0.0
# 6   11  Berlin  2003.0  24 bis unter 32 EGE     9.0
# 10  11  Berlin  2003.0               Gesamt    86.0
# 4   11  Berlin  2003.0   8 bis unter 16 EGE     0.0
# 3   11  Berlin  2003.0    2 bis unter 8 EGE    13.0
# 2   11  Berlin  2003.0          unter 2 EGE     3.0
# 5   11  Berlin  2003.0  16 bis unter 24 EGE    10.0
# 11  11  Berlin  2005.0               Gesamt    89.0
# 19  11  Berlin  2007.0     60 oder mehr EGE    26.0
# 12  11  Berlin  2007.0          unter 2 EGE     3.0
# 13  11  Berlin  2007.0    2 bis unter 8 EGE    20.0
# 14  11  Berlin  2007.0   8 bis unter 16 EGE    18.0
# 15  11  Berlin  2007.0  16 bis unter 24 EGE     4.0
# ...

# %%
#forage plants
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'FRUNW4': 'ALL'})
Farms_Arable.add_field('FRUNW4')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name    year    FRUNW4  BETR09  \
# 0   11  Berlin  1999.0  zusammen    18.0
# 1   11  Berlin  1999.0  Silomais     0.0
# 2   11  Berlin  1999.0    Gesamt   103.0
# 3   11  Berlin  2001.0    Gesamt    90.0
# 4   11  Berlin  2003.0  zusammen    13.0
# 5   11  Berlin  2003.0  Silomais     3.0
# 6   11  Berlin  2003.0    Gesamt    86.0
# 7   11  Berlin  2005.0    Gesamt    89.0
# 8   11  Berlin  2007.0  Silomais     3.0
# 9   11  Berlin  2007.0  zusammen    27.0
# 10  11  Berlin  2007.0    Gesamt    85.0
#
#                          BETR09_source_title_de BETR09_source_valid_from  \
# 0   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 1   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 2   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 3   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# 4   Allgemeine Agrarstrukturerhebung (bis 2007)      1999-05-31T00:00:00
# ...

# %%
#type of management
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'BTRAT1': 'ALL'})
Farms_Arable.add_field('BTRAT1')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id    name                                     BTRAT1    year  BETR09  \
# 0   11  Berlin   Landw. Betriebe mit ökologischem Landbau  1999.0     1.0
# 1   11  Berlin  Landw. Betriebe ohne ökologischen Landbau  1999.0    98.0
# 2   11  Berlin                                     Gesamt  1999.0   103.0
# 3   11  Berlin  Landw. Betriebe ohne ökologischen Landbau  2001.0    90.0
# 4   11  Berlin                                     Gesamt  2001.0    90.0
# 5   11  Berlin   Landw. Betriebe mit ökologischem Landbau  2003.0     1.0
# 6   11  Berlin  Landw. Betriebe ohne ökologischen Landbau  2003.0    85.0
# 7   11  Berlin                                     Gesamt  2003.0    86.0
# 8   11  Berlin  Landw. Betriebe ohne ökologischen Landbau  2005.0    88.0
# 9   11  Berlin   Landw. Betriebe mit ökologischem Landbau  2005.0     1.0
# 10  11  Berlin                                     Gesamt  2005.0    89.0
# 11  11  Berlin   Landw. Betriebe mit ökologischem Landbau  2007.0     4.0
# ...

# %%
#type of operation
query = Query.region(['110', '11000', '11'])
Farms_Arable = query.add_field('BETR09')
Farms_Arable.add_args({'BEWAT2': 'ALL'})
Farms_Arable.add_field('BEWAT2')
query.results(verbose_enums=True).sort_values('year')
