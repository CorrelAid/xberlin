# %%
#Import the helper functions 'get_all_regions' and 'get_statistics'
#Import the module Query for the main functionality
import os
if not os.path.basename(os.getcwd()) == "datenguide-python":
    os.chdir("..")

from datenguidepy.query_helper import get_regions, get_statistics
from datenguidepy import Query
import pandas as pd
import matplotlib
# %matplotlib inline

pd.set_option('display.max_colwidth', 150)

# %%
#Regions IDs for Berlin
get_regions().query("name == 'Berlin'")
# Out:
#              name  level parent
# region_id
# 11         Berlin  nuts1     DG
# 110        Berlin  nuts2     11
# 11000      Berlin  nuts3    110

# %%
#Get statistic IDs in English to data that contain "agri" string
get_statistics(target_language = 'en').query('long_description.str.contains("agri")', engine='python')
# Out:
#                                                  short_description  \
# statistic
# FLC048                            LF on farms with organic farming
# ERW046                                                   workforce
# LST009                                                 performance
# BTR034                        Agricultural holdings with livestock
# BTR038                                      Farms with 100 U.M. GV
# VIE003                                                   livestock
# BTR010                                                       farms
# FLC017                                  Utilized agricultural area
# BTR011                                Farms (sole proprietorships)
# BTR030                                  Agricultura. Organic farms
# ETG009                                        Lease payment per ha
# AI0201                       Population density (people per sq km)
# AI0102                         Share recreation area to total area
# ...

# %%
#get the data for farms
query = Query.region(['110', '11000', '11'])
farms = query.add_field('BTR010')
query.results()
# Out:
#       id    name  year  BTR010  \
# 0    110  Berlin  2016      52
# 0  11000  Berlin  2016      52
# 0     11  Berlin  2010      66
# 1     11  Berlin  2016      52
#
#                            BTR010_source_title_de BTR010_source_valid_from  \
# 0  Agrarstrukturerhebung / Landwirtschaftszählung      2010-01-01T00:00:00
# 0  Agrarstrukturerhebung / Landwirtschaftszählung      2010-01-01T00:00:00
# 0  Agrarstrukturerhebung / Landwirtschaftszählung      2010-01-01T00:00:00
# 1  Agrarstrukturerhebung / Landwirtschaftszählung      2010-01-01T00:00:00
#
#   BTR010_source_periodicity BTR010_source_name BTR010_source_url
# 0             ZEHNJAEHRLICH              41141              None
# 0             ZEHNJAEHRLICH              41141              None
# 0             ZEHNJAEHRLICH              41141              None
# 1             ZEHNJAEHRLICH              41141              None

# %%
#farms
# 
#  Explanation for the following statistics (s): 41141 agricultural census
# Connotation: Report county
# Since 2010, only farms are with a utilized agricultural area (UAA) of at least 5 hectares or at least
# - 10 cattle or pigs 50 or 10 sows or in each case 20 sheep or goats 20 or 1000 or poultry - 0,5 ha 0,5 ha hops or tobacco or - 1.0 ha permanent crops in the open field or per 0.5 ha fruit growing construction, vine or tree nursery area or - 0.5 ha vegetables or strawberries, outdoor ha or 0.3 Blu men or ornamental plants outdoor or - 0.1 ha crops under glass or other accessible protective covers or 0.1 ha edible mushrooms
# involved in the treatment.
# Connotation: Farms
#  An agricultural holding is a technical and economic unit comprising one of the above "Report Group" minimum sizes under single management and agricultural products or in addition, services and other products produces. The intention to make a profit is not necessary.

# %%
#meta data
farms.get_info()
# Out:
# kind:
# OBJECT
#
# description:
# Landwirtschaftliche Betriebe
#
# arguments:
# year: LIST of type SCALAR(Int)
#
# statistics: LIST of type ENUM(BTR010Statistics)
# enum values:
# R41141: Agrarstrukturerhebung / Landwirtschaftszählung
#
# FLCG06: LIST of type ENUM(FLCG06)
# enum values:
# FLCHA000B050: unter 5 ha
# FLCHA050B100: 5 bis unter 10 ha
# FLCHB010B020: 10 bis unter 20 ha
# FLCHB020B050: 20 bis unter 50 ha
# FLCHB050B100: 50 bis unter 100 ha
# FLCHC010B020: 100 bis unter 200 ha
# FLCHC020UM: 200 und mehr ha
# GESAMT: Gesamt
#
# EIGVH1: LIST of type ENUM(EIGVH1)
# enum values:
# FLC_PACHT_01: Betriebe mit gepachteter selbstbewirtschafteter LF
# FLC_PACHT_02: Von Familienangehörigen gepachtete LF
# FLC_PACHT_03: Von anderen Verpächtern gepachtete LF
# FLC_SELSBT: Betriebe mit eigener selbstbewirtschafteter LF
# FLC_UNENTG: Unentgeltlich zur Bewirtschaftung erhaltene LF
# GESAMT: Gesamt
#
# RECF01: LIST of type ENUM(RECF01)
# enum values:
# RECHTSF11: Einzelunternehmen
# ...

# %%
#area
query = Query.region(['110', '11000', '11'])
Livestock = query.add_field('BTR010')
Livestock.add_args({'FLCG06': 'ALL'})
Livestock.add_field('FLCG06')
query.results(verbose_enums=True).sort_values('year')
# Out:
#        id    name                FLCG06  year  BTR010  \
# 7      11  Berlin       200 und mehr ha  2010       0
# 6      11  Berlin  100 bis unter 200 ha  2010       7
# 5      11  Berlin   50 bis unter 100 ha  2010       6
# 4      11  Berlin    20 bis unter 50 ha  2010      13
# 3      11  Berlin    10 bis unter 20 ha  2010       9
# 2      11  Berlin     5 bis unter 10 ha  2010       0
# 1      11  Berlin            unter 5 ha  2010       0
# 0      11  Berlin                Gesamt  2010      66
# 0     110  Berlin                Gesamt  2016      52
# 13     11  Berlin   50 bis unter 100 ha  2016       7
# 12     11  Berlin    20 bis unter 50 ha  2016       8
# 11     11  Berlin    10 bis unter 20 ha  2016      11
# 10     11  Berlin     5 bis unter 10 ha  2016       5
# 9      11  Berlin            unter 5 ha  2016      15
# 8      11  Berlin                Gesamt  2016      52
# 7   11000  Berlin            unter 5 ha  2016      15
# ...

# %%
#management
query = Query.region(['110', '11000', '11'])
Livestock = query.add_field('BTR010')
Livestock.add_args({'EIGVH1': 'ALL'})
Livestock.add_field('EIGVH1')
query.results(verbose_enums=True).sort_values('year')
# Out:
#       id    name                                              EIGVH1  year  \
# 0     11  Berlin               Von anderen Verpächtern gepachtete LF  2010
# 1     11  Berlin      Betriebe mit eigener selbstbewirtschafteter LF  2010
# 2     11  Berlin      Unentgeltlich zur Bewirtschaftung erhaltene LF  2010
# 3     11  Berlin  Betriebe mit gepachteter selbstbewirtschafteter LF  2010
# 4     11  Berlin               Von Familienangehörigen gepachtete LF  2010
# 5     11  Berlin                                              Gesamt  2010
# 0    110  Berlin                                              Gesamt  2016
# 0  11000  Berlin                                              Gesamt  2016
# 6     11  Berlin                                              Gesamt  2016
#
#    BTR010                          BTR010_source_title_de  \
# 0       0  Agrarstrukturerhebung / Landwirtschaftszählung
# 1      36  Agrarstrukturerhebung / Landwirtschaftszählung
# ...

# %%
#ownership
query = Query.region(['110', '11000', '11'])
Livestock = query.add_field('BTR010')
Livestock.add_args({'RECF01': 'ALL'})
Livestock.add_field('RECF01')
query.results(verbose_enums=True).sort_values('year')
# Out:
#       id    name  year                                   RECF01  BTR010  \
# 0     11  Berlin  2010           Einzelunternehmen, Haupterwerb      30
# 5     11  Berlin  2010                                   Gesamt      66
# 4     11  Berlin  2010                     Juristische Personen       0
# 3     11  Berlin  2010  Personengemeinschaften, -gesellschaften       0
# 2     11  Berlin  2010                        Einzelunternehmen      41
# 1     11  Berlin  2010           Einzelunternehmen, Nebenerwerb      11
# 7     11  Berlin  2016                        Einzelunternehmen      38
# 6     11  Berlin  2016                                   Gesamt      52
# 0    110  Berlin  2016                                   Gesamt      52
# 3  11000  Berlin  2016                                   Gesamt      52
# 2  11000  Berlin  2016                     Juristische Personen       9
# 1  11000  Berlin  2016  Personengemeinschaften, -gesellschaften       5
# ...

# %%
#land type
query = Query.region(['110', '11000', '11'])
Livestock = query.add_field('BTR010')
Livestock.add_args({'BNZAT6': 'ALL'})
Livestock.add_field('BNZAT6')
query.results(verbose_enums=True).sort_values('year')
# Out:
#       id    name  year               BNZAT6  BTR010  \
# 0     11  Berlin  2010               Gesamt      66
# 1     11  Berlin  2010  Ackerland insgesamt      53
# 2     11  Berlin  2010        Dauerkulturen       0
# 3     11  Berlin  2010        Dauergrünland      36
# 0    110  Berlin  2016               Gesamt      52
# 1    110  Berlin  2016  Ackerland insgesamt      37
# 2    110  Berlin  2016        Dauerkulturen       9
# 3    110  Berlin  2016        Dauergrünland      35
# 0  11000  Berlin  2016  Ackerland insgesamt      37
# 1  11000  Berlin  2016               Gesamt      52
# 2  11000  Berlin  2016        Dauerkulturen       9
# 3  11000  Berlin  2016        Dauergrünland      35
# 4     11  Berlin  2016               Gesamt      52
# 5     11  Berlin  2016  Ackerland insgesamt      37
# 6     11  Berlin  2016        Dauerkulturen       9
# 7     11  Berlin  2016        Dauergrünland      35
#
# ...
