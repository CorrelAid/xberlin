# %%
#Import the helper functions 'get_all_regions' and 'get_statistics'
#Import the module Query for the main functionality
import os
if not os.path.basename(os.getcwd()) == "datenguide-python":
    os.chdir("..")

from datenguidepy.query_helper import get_regions, get_statistics
from datenguidepy import Query
import pandas as pd
import matplotlib
# %matplotlib inline

pd.set_option('display.max_colwidth', 150)

# %%
#Regions IDs for Germany states
get_regions().query("level == 'nuts1'")
# Out:
#                               name  level parent
# region_id
# 10                        Saarland  nuts1     DG
# 11                          Berlin  nuts1     DG
# 12                     Brandenburg  nuts1     DG
# 13          Mecklenburg-Vorpommern  nuts1     DG
# 14                         Sachsen  nuts1     DG
# 15                  Sachsen-Anhalt  nuts1     DG
# 16                       Thüringen  nuts1     DG
# 01              Schleswig-Holstein  nuts1     DG
# 02                         Hamburg  nuts1     DG
# 03                   Niedersachsen  nuts1     DG
# 04                          Bremen  nuts1     DG
# 05             Nordrhein-Westfalen  nuts1     DG
# 06                          Hessen  nuts1     DG
# 07                 Rheinland-Pfalz  nuts1     DG
# 08         Baden-Württemberg, Land  nuts1     DG
# 09                          Bayern  nuts1     DG

# %%
#Serious accidents involving damage to property in the strict sense
# 
#  Explanation for the following statistics (s): 46241 Statistics of road accidents
#  Connotation Serious accidents involving material damage
#  These include "serious accidents involving damage to property in the strict sense" and "other accidents under the influence of intoxicating substances". "Serious accidents involving damage to property in the strict sense" are accidents in which a criminal offense or a misdemeanor (fine) was present, while at least one vehicle due to an accident damage will be towed from the accident site had (this also includes cases under the influence of intoxicating substances).
# "Other accidents under the influence of intoxicating agents" are accidents in which all car involved were still roadworthy and at the same time was at least one accident participant under the influence of intoxicating substances.
# This excludes all other property damage accidents without the influence of intoxicating substances.

# %%
#meta data
accidents_property_damage.get_info()
# Out:
# kind:
# OBJECT
#
# description:
# Schwerwiegende Unfälle mit Sachschäden i.e.S.
#
# arguments:
# year: LIST of type SCALAR(Int)
#
# statistics: LIST of type ENUM(VER005Statistics)
# enum values:
# R46241: Statistik der Straßenverkehrsunfälle
#
# fields:
# id: Interne eindeutige ID
# year: Jahr des Stichtages
# value: Wert
# source: Quellenverweis zur GENESIS Regionaldatenbank
#
# enum values:
# None

# %%
#get the data for Serious accidents involving property damage i.e.S. ordered by years
query = Query.region(['01', '02', '03','04', '05','06', '07', '08', '09', '10', '11', '12', '13', '14', '15', '16'])
accidents_property_damage = query.add_field('VER005')
query.results(verbose_enums=True).sort_values('year')
# Out:
#     id                name  year  VER005  \
# 0   01  Schleswig-Holstein  1995    3544
# 0   15      Sachsen-Anhalt  1995    6812
# 1   15      Sachsen-Anhalt  1995    6812
# 2   15      Sachsen-Anhalt  1995    6812
# 2   06              Hessen  1995   10100
# ..  ..                 ...   ...     ...
# 69  03       Niedersachsen  2018       0
# 69  02             Hamburg  2018       0
# 69  01  Schleswig-Holstein  2018       0
# 69  15      Sachsen-Anhalt  2018       0
# 69  16           Thüringen  2018       0
#
#                   VER005_source_title_de VER005_source_valid_from  \
# 0   Statistik der Straßenverkehrsunfälle      1995-12-31T00:00:00
# 0   Statistik der Straßenverkehrsunfälle      1995-12-31T00:00:00
# 1   Statistik der Straßenverkehrsunfälle      1995-12-31T00:00:00
# 2   Statistik der Straßenverkehrsunfälle      1995-12-31T00:00:00
# 2   Statistik der Straßenverkehrsunfälle      1995-12-31T00:00:00
# ..                                   ...                      ...
# ...
